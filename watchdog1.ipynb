# %% [markdown]
# # Monitor block of MAPE-K

# %%
# import sys
# import time
# import logging
# from watchdog.observers import Observer
# from watchdog.events import FileSystemEventHandler
# import os
# import pandas as pd
# import docx
# import pandasql as ps
# import os
# from pathlib import Path
# from fuzzywuzzy import fuzz
# from fuzzywuzzy import process
# from pandasql import sqldf



# class Handler(FileSystemEventHandler):
#     def on_modified(self,event):
#         for filename in os.listdir(folder_to_check):
#             src=folder_to_check+'/'+filename
#             new_dest=folder_destination+'/'+filename
#             os.rename(src,new_dest)
#             filenamechange()
            
# #             for file in os.listdir(folder_destination):
# #                 os.rename(file,new_file_name)
            
            
            
# folder_to_check='E:/MS/Thesis/new requirements'
# folder_destination='E:/MS/Thesis/testing'
# new_file_name = 'URStest.docx'
# monitor=Observer()
# event_handler=Handler()
# monitor.schedule(event_handler,folder_to_check,recursive=True)
# print("watchdog starts")
# monitor.start()
# print("watchdog after start")
# fullText = []

# def filenamechange():
#     for file in os.listdir(folder_destination):
#         os.rename(folder_destination+'/'+file, folder_destination+'/'+new_file_name)

        
# def AnalyseFile(filename):
#     doc = docx.Document(filename)
#     for para in doc.paragraphs:
#         fullText.append(para.text)
# #         if "goal setting" and "demarcation criteria" and "mission" and "Nonfunctional requirements" and "Functional requirements" and "User interface requirements" and "quality target setting" in para:
# #             print("ok")
# #             #PlanDatasetCheck()
# #         else:
# #             print("not ok")
# #     return '\n'.join(fullText)
# # print("--------------------------------")     
    


# # try:
# #     while True:
# #         isFile = os.path.isfile('E:/MS/Thesis/testing/URStest.docx')
# #         if  os.path.isfile('E:/MS/Thesis/testing/URStest.docx'):
# #             AnalyseFile('E:/MS/Thesis/testing/URStest.docx')
# #         else:
# #             time.sleep(10)
# #             print("timer running")
# # except KeyboardInterrupt:
# #     monitor.stop()
    
    
# try:
#     while True:
#         time.sleep(10)
#         print("timer running")
# except KeyboardInterrupt:
#     monitor.stop()
    
# monitor.join()



import sys
import time
import logging
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler
import os

class Handler(FileSystemEventHandler):
    def on_modified(self,event):
        for filename in os.listdir(folder_to_check):
            src=folder_to_check+'/'+filename
            new_dest=folder_destination+'/'+filename
            os.rename(src,new_dest)
            filenamechange()
            
#             for file in os.listdir(folder_destination):
#                 os.rename(file,new_file_name)
            
            
            
folder_to_check='E:/MS/Thesis/new requirements'
folder_destination='E:/MS/Thesis/testing'
new_file_name = 'URStest.docx'
monitor=Observer()
event_handler=Handler()
monitor.schedule(event_handler,folder_to_check,recursive=True)
print("watchdog starts")
monitor.start()
print("watchdog after start")

def filenamechange():
    for file in os.listdir(folder_destination):
        os.rename(folder_destination+'/'+file, folder_destination+'/'+new_file_name)
 
    


try:
    while True:
        time.sleep(10)
        print("timer running")
except KeyboardInterrupt:
    monitor.stop()
    
monitor.join()
# Out:
# watchdog starts
# watchdog after start
# timer running
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "C:\Users\LENOVO\anaconda3\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "C:\Users\LENOVO\anaconda3\lib\site-packages\watchdog\observers\api.py", line 199, in run
#     self.dispatch_events(self.event_queue, self.timeout)
#   File "C:\Users\LENOVO\anaconda3\lib\site-packages\watchdog\observers\api.py", line 372, in dispatch_events
#     handler.dispatch(event)
#   File "C:\Users\LENOVO\anaconda3\lib\site-packages\watchdog\events.py", line 272, in dispatch
#     {
#   File "C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10696\2732812067.py", line 96, in on_modified
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'E:/MS/Thesis/new requirements/URStest.docx' -> 'E:/MS/Thesis/testing/URStest.docx'
# timer running
# timer running
# timer running
# timer running
# ...

# %%
import os

#isFile = os.path.isfile('E:/MS/Thesis/testing/URStest.docx')

if  os.path.isfile('E:/MS/Thesis/testing/URStest.docx'):
    print("ok")


#print(isFile)
# Out:
# ok
# True

# %%
with open('E:/MS/Thesis/testing/URStest.docx') as file:
    contents = file.readlines()
    search_word = 'Nonfunctional requirements'
    if search_word in contents:
        print ('word found')
    else:
        print ('word not found')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6240\3476864341.py in <module>
#       1 with open('E:/MS/Thesis/testing/URStest.docx') as file:
# ----> 2     contents = file.readlines()
#       3     search_word = 'Nonfunctional requirements'
#       4     if search_word in contents:
#       5         print ('word found')
#
# ~\anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 604: character maps to <undefined>

# %% [markdown]
# # Analyze block of MAPE-K

# %%
# import docx

# def ReadingTextDocuments(fileName):
#     doc= docx.Document(fileName)
    
#     completedText = []
    
#     for paragraph in doc.paragraphs:
#         completedText.append(paragraph.text)
        
#     return '\n' .join(completedText)

# print(ReadingTextDocuments('File.docx')

fullText = []

import docx

def AnalyseFile(filename):
    doc = docx.Document(filename)
    for para in doc.paragraphs:
        fullText.append(para.text)
        if "goal setting" and "demarcation criteria" and "mission" and "Nonfunctional requirements" and "Functional requirements" and "User interface requirements" and "quality target setting" in fullText:
            print("ok")
            PlanDatasetCheck()
        else:
            print("not ok")
    return '\n'.join(fullText)
print("--------------------------------")



def PlanDatasetCheck():
 
    fileName= Path('E:/MS/Thesis/Ilias/internal/URStest.docx').stem

    DatabaseDF = pd.read_excel('E:/MS/Thesis/data set/Database.xlsx')

#df.head(5)


Text = docx.Document('E:/MS/Thesis/Ilias/internal/URStest.docx')
#data={}

for table in Text.tables:
    for row in table.rows:
        for cell in row.cells:
            #print (cell.text)
            #print("-------------------------")
            
            if "LFA" in cell.text:
                #print (cell.text)
                data = [[cell.text for cell in row.cells] for row in table.rows]
            #data = cell.text
#df = pd.DataFrame(data)  
#data = [[cell.text for cell in row.cells] for row in table.rows]
            
#df_req = pd.DataFrame(cell.text)
df_req = pd.DataFrame(data) 
headers =  ["Sequence", "URStest"]
df_req.columns = headers

#writing USR1 requirements dataframe to excel

with pd.ExcelWriter(r'E:\MS\Thesis\data set\extracted req.xlsx') as writer:
    df_req.to_excel(writer,sheet_name='functional req', index=False)
 
      
matched_req = []
soft_com = []

for ind in df_req.index:
    USR = df_req['URStest'][ind]
#     print("USR: ", USR)
#     print("-----------------------------")
    for ind1 in DatabaseDF.index:
        Specification_database = DatabaseDF['database_requirements'][ind1]
#         print("database:",Specification_database )
#         print("-----------------------------")
        matched_token=fuzz.token_sort_ratio(USR,Specification_database)
        if matched_token> 80:
            matched_req.append({"user_id": ind,"user": USR,"requirement": Specification_database,"accuracy": matched_token, "Keyword": DatabaseDF["Keyword"][ind1],
                                "sft_com": DatabaseDF["Software complexity"][ind1]})
            #print(matched_req)    
# masterDf = pd.DataFrame(matched_req)
# masterDf.head()

fuzzy = pd.DataFrame(matched_req)
fuzzy.head()


with pd.ExcelWriter(r'E:\MS\Thesis\data set\fuzzy.xlsx') as writer:
    fuzzy.to_excel(writer,sheet_name='fuzzy', index=False)
    
output = sqldf("select Keyword, round(avg(sft_com),3) as software_complexity from fuzzy group by keyword")

output1 = output.T

# with pd.ExcelWriter(r'F:\MS\Thesis\data set\Dataset.xlsx') as writer:
#     output1.to_excel(writer,sheet_name='dataset' , index=False)
# Out:
# --------------------------------
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# not ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ------------------------end--------------------

# %%
print(fullText)
# Out:
# ['', '\nDocument version management', '', '', 'Table of Contents', '0 \ttable of contents \t2', '1 \ttarget setting \t4', '1.1 \tMust criteria \t4', '1.2 \tDesire criteria \t4', '1.3 \tDelimitation criteria \t4', '2 \tinsert \t4', '2.1 Areas of \tapplication \t4', '2.2 \tTarget groups \t4', '2.3 \tOperating conditions \t5', '3 \tenvironment \t5', '3.1 \tSoftware \t5', '3.2 \tHardware \t5', '3.3 \tSystem interfaces \t5', '4 \tFunctional requirements \t5', '5 \tNon-functional requirements \t6', '6 \tRequirements for the user interface \t6', '7 \tquality target setting \t7', '8 \tGlobal test scenarios/cases \t7', '9 \tdevelopment environment \t8', '9.1 \tSoftware \t8', '9.1.1 \tProgramming languages \t8', '9.1.2 \tPrograms \t8', '9.1.3 \tOperating system \t8', '9.2 \tHardware \t8', '9.3 \tOrgware \t8', '9.3.1 \tDocument editing \t8', '9.3.2 \tCommunication \t8', '9.4 \tDevelopment interfaces \t8', '10 \tImplementation \t9', '11 \tsupplements \t9', '', '\ngoal setting', 'must criteria', 
# ...

# %%
import pandas as pd


if_count=0
for_count=0
while_count=0
func_count=0
case_count=0
until_count=0

#datalist1 = []


f= open ("BatteryDisplay.c", "r")
seperator = "//"
LineList=f.readlines()

for line in LineList:
    line= line.split(seperator, 1) [0]
    if " if " in line:
        if_count+=1
    if " for " in line:
        for_count+=1
    if " while " in line:
        while_count+=1
    if "case"in line:
        case_count+=1
    if "until" in line:
        until_count+=1
    DTO["number of If"]=if_count
    DTO["number of for"]=for_count
    DTO["number of while"]=while_count
    DTO["number of swith cases"]=case_count
    DTO["number of do until"]= until_count
    datalist1.append(DTO)
    DTO = {"number of If": None,
           "number of for": None,
           "number of while": None,
           "number of swith case":None,
           "number of do until":None}
     
df=pd.DataFrame(datalist1, columns=['number of If','number of for','number of while','number of swith case','number of do until'])
print(df.head())
       
print(if_count,for_count,while_count,case_count,until_count)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization

#-- plotly
import plotly.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
#--

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
['jm1.csv', 'about JM1 Dataset.txt', 'jm1.arff']
data = pd.read_csv('../input/jm1.csv')
About this Software Defect Prediction Dataset
